# %% [markdown]
# <a href="https://colab.research.google.com/github/MostafaELFEEL/Machine-Learning-and-Deep-Learning-Projects/blob/main/CNN_with_kfold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import time
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score

# ---------------------------------------------------------
# Load and Normalize CIFAR-100 Dataset
# ---------------------------------------------------------
(train_images, train_labels), _ = tf.keras.datasets.cifar100.load_data()
train_labels = train_labels.ravel()

train_images = train_images.astype('float32') / 255.0
mean = np.mean(train_images, axis=(0, 1, 2))
std = np.std(train_images, axis=(0, 1, 2))
train_images_norm = (train_images - mean) / std

# ---------------------------------------------------------
# Define Model Factory Function
# ---------------------------------------------------------
def create_model():
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(100, activation='softmax')
    ])
    model.compile(
        optimizer='adam',
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
        metrics=['accuracy']
    )
    return model

# ---------------------------------------------------------
# K-Fold Cross-Validation Setup
# ---------------------------------------------------------
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

fold_accuracies = []

for fold, (train_idx, val_idx) in enumerate(kfold.split(train_images_norm, train_labels)):
    print(f"\n🌟 Fold {fold+1}/{num_folds}")

    X_train, X_val = train_images_norm[train_idx], train_images_norm[val_idx]
    y_train, y_val = train_labels[train_idx], train_labels[val_idx]

    model = create_model()

    early_stop = tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)

    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=30,
        batch_size=64,
        callbacks=[early_stop],
        verbose=2
    )

    val_loss, val_acc = model.evaluate(X_val, y_val, verbose=0)
    print(f"✅ Fold {fold+1} Accuracy: {val_acc:.4f}")
    fold_accuracies.append(val_acc)

# ---------------------------------------------------------
# Final Cross-Validation Summary
# ---------------------------------------------------------
print("\n📊 Cross-Validation Results:")
for i, acc in enumerate(fold_accuracies):
    print(f"Fold {i+1} Accuracy: {acc:.4f}")
print(f"\nAverage Accuracy: {np.mean(fold_accuracies):.4f}")
print(f"Standard Deviation: {np.std(fold_accuracies):.4f}")
# Out:
# 🌟 Fold 1/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 625/625 - 7s - 11ms/step - accuracy: 0.0507 - loss: 4.3123 - val_accuracy: 0.1178 - val_loss: 3.8498
# Epoch 2/30
# 625/625 - 3s - 5ms/step - accuracy: 0.0999 - loss: 3.8948 - val_accuracy: 0.1674 - val_loss: 3.5408
# Epoch 3/30
# 625/625 - 3s - 4ms/step - accuracy: 0.1362 - loss: 3.6666 - val_accuracy: 0.2090 - val_loss: 3.3469
# Epoch 4/30
# 625/625 - 3s - 4ms/step - accuracy: 0.1611 - loss: 3.5165 - val_accuracy: 0.2343 - val_loss: 3.1981
# Epoch 5/30
# 625/625 - 3s - 5ms/step - accuracy: 0.1792 - loss: 3.4062 - val_accuracy: 0.2526 - val_loss: 3.1024
# Epoch 6/30
# 625/625 - 3s - 5ms/step - accuracy: 0.1995 - loss: 3.3132 - val_accuracy: 0.2633 - val_loss: 3.0296
# Epoch 7/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2118 - loss: 3.2429 - val_accuracy: 0.2772 - val_loss: 2.9715
# Epoch 8/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2186 - loss: 3.1871 - val_accuracy: 0.2841 - val_loss: 2.8952
# Epoch 9/30
# 625/625 - 6s - 9ms/step - accuracy: 0.2329 - loss: 3.1253 - val_accuracy: 0.3011 - val_loss: 2.8557
# Epoch 10/30
# 625/625 - 4s - 7ms/step - accuracy: 0.2358 - loss: 3.0954 - val_accuracy: 0.2976 - val_loss: 2.8621
# Epoch 11/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2475 - loss: 3.0484 - val_accuracy: 0.3090 - val_loss: 2.8047
# Epoch 12/30
# 625/625 - 6s - 9ms/step - accuracy: 0.2521 - loss: 3.0064 - val_accuracy: 0.3106 - val_loss: 2.7854
# Epoch 13/30
# 625/625 - 4s - 7ms/step - accuracy: 0.2585 - loss: 2.9808 - val_accuracy: 0.3089 - val_loss: 2.8023
# Epoch 14/30
# 625/625 - 5s - 9ms/step - accuracy: 0.2619 - loss: 2.9545 - val_accuracy: 0.3186 - val_loss: 2.7508
# Epoch 15/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2656 - loss: 2.9303 - val_accuracy: 0.3185 - val_loss: 2.7472
# Epoch 16/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2706 - loss: 2.9070 - val_accuracy: 0.3234 - val_loss: 2.7227
# Epoch 17/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2758 - loss: 2.8843 - val_accuracy: 0.3250 - val_loss: 2.7180
# Epoch 18/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2791 - loss: 2.8650 - val_accuracy: 0.3286 - val_loss: 2.7102
# Epoch 19/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2815 - loss: 2.8399 - val_accuracy: 0.3333 - val_loss: 2.7016
# Epoch 20/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2868 - loss: 2.8173 - val_accuracy: 0.3241 - val_loss: 2.7151
# Epoch 21/30
# 625/625 - 5s - 9ms/step - accuracy: 0.2866 - loss: 2.8038 - val_accuracy: 0.3318 - val_loss: 2.6872
# Epoch 22/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2913 - loss: 2.7863 - val_accuracy: 0.3126 - val_loss: 2.7727
# Epoch 23/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2933 - loss: 2.7658 - val_accuracy: 0.3271 - val_loss: 2.7001
# Epoch 24/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2948 - loss: 2.7580 - val_accuracy: 0.3362 - val_loss: 2.7099
# Epoch 25/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2971 - loss: 2.7466 - val_accuracy: 0.3348 - val_loss: 2.6900
# Epoch 26/30
# 625/625 - 3s - 4ms/step - accuracy: 0.3013 - loss: 2.7190 - val_accuracy: 0.3276 - val_loss: 2.7114
# ✅ Fold 1 Accuracy: 0.3318
#
# 🌟 Fold 2/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 625/625 - 7s - 12ms/step - accuracy: 0.0534 - loss: 4.2880 - val_accuracy: 0.1343 - val_loss: 3.8446
# Epoch 2/30
# 625/625 - 3s - 5ms/step - accuracy: 0.1115 - loss: 3.8331 - val_accuracy: 0.1801 - val_loss: 3.4930
# Epoch 3/30
# 625/625 - 5s - 8ms/step - accuracy: 0.1519 - loss: 3.5968 - val_accuracy: 0.2201 - val_loss: 3.2811
# Epoch 4/30
# 625/625 - 6s - 9ms/step - accuracy: 0.1813 - loss: 3.4321 - val_accuracy: 0.2454 - val_loss: 3.1276
# Epoch 5/30
# 625/625 - 4s - 7ms/step - accuracy: 0.2026 - loss: 3.3206 - val_accuracy: 0.2641 - val_loss: 3.0404
# Epoch 6/30
# 625/625 - 5s - 9ms/step - accuracy: 0.2189 - loss: 3.2261 - val_accuracy: 0.2771 - val_loss: 3.0025
# Epoch 7/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2306 - loss: 3.1519 - val_accuracy: 0.2880 - val_loss: 2.9189
# Epoch 8/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2451 - loss: 3.0828 - val_accuracy: 0.3016 - val_loss: 2.8736
# Epoch 9/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2556 - loss: 3.0280 - val_accuracy: 0.3025 - val_loss: 2.8388
# Epoch 10/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2633 - loss: 2.9851 - val_accuracy: 0.3089 - val_loss: 2.8713
# Epoch 11/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2696 - loss: 2.9527 - val_accuracy: 0.3137 - val_loss: 2.7911
# Epoch 12/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2736 - loss: 2.9168 - val_accuracy: 0.3183 - val_loss: 2.7899
# Epoch 13/30
# 625/625 - 5s - 8ms/step - accuracy: 0.2818 - loss: 2.8794 - val_accuracy: 0.3267 - val_loss: 2.7387
# Epoch 14/30
# 625/625 - 5s - 8ms/step - accuracy: 0.2876 - loss: 2.8491 - val_accuracy: 0.3275 - val_loss: 2.7351
# Epoch 15/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2928 - loss: 2.8221 - val_accuracy: 0.3336 - val_loss: 2.6984
# Epoch 16/30
# 625/625 - 6s - 9ms/step - accuracy: 0.2937 - loss: 2.8031 - val_accuracy: 0.3280 - val_loss: 2.7381
# Epoch 17/30
# 625/625 - 5s - 8ms/step - accuracy: 0.2993 - loss: 2.7828 - val_accuracy: 0.3390 - val_loss: 2.6897
# Epoch 18/30
# 625/625 - 3s - 4ms/step - accuracy: 0.3023 - loss: 2.7539 - val_accuracy: 0.3352 - val_loss: 2.6906
# Epoch 19/30
# 625/625 - 3s - 5ms/step - accuracy: 0.3078 - loss: 2.7389 - val_accuracy: 0.3361 - val_loss: 2.6799
# Epoch 20/30
# 625/625 - 3s - 5ms/step - accuracy: 0.3124 - loss: 2.7180 - val_accuracy: 0.3363 - val_loss: 2.6994
# Epoch 21/30
# 625/625 - 2s - 4ms/step - accuracy: 0.3131 - loss: 2.7005 - val_accuracy: 0.3407 - val_loss: 2.6583
# Epoch 22/30
# 625/625 - 3s - 4ms/step - accuracy: 0.3178 - loss: 2.6894 - val_accuracy: 0.3407 - val_loss: 2.6643
# Epoch 23/30
# 625/625 - 2s - 4ms/step - accuracy: 0.3207 - loss: 2.6653 - val_accuracy: 0.3469 - val_loss: 2.6699
# Epoch 24/30
# 625/625 - 3s - 5ms/step - accuracy: 0.3200 - loss: 2.6633 - val_accuracy: 0.3469 - val_loss: 2.6427
# Epoch 25/30
# 625/625 - 5s - 8ms/step - accuracy: 0.3250 - loss: 2.6354 - val_accuracy: 0.3392 - val_loss: 2.6650
# Epoch 26/30
# 625/625 - 3s - 4ms/step - accuracy: 0.3275 - loss: 2.6273 - val_accuracy: 0.3340 - val_loss: 2.6917
# Epoch 27/30
# 625/625 - 6s - 9ms/step - accuracy: 0.3273 - loss: 2.6127 - val_accuracy: 0.3495 - val_loss: 2.6368
# Epoch 28/30
# 625/625 - 3s - 4ms/step - accuracy: 0.3341 - loss: 2.5868 - val_accuracy: 0.3468 - val_loss: 2.6539
# Epoch 29/30
# 625/625 - 3s - 4ms/step - accuracy: 0.3358 - loss: 2.5823 - val_accuracy: 0.3523 - val_loss: 2.6483
# Epoch 30/30
# 625/625 - 3s - 4ms/step - accuracy: 0.3405 - loss: 2.5633 - val_accuracy: 0.3457 - val_loss: 2.6717
# ✅ Fold 2 Accuracy: 0.3495
#
# 🌟 Fold 3/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 625/625 - 7s - 11ms/step - accuracy: 0.0521 - loss: 4.3064 - val_accuracy: 0.1085 - val_loss: 3.8870
# Epoch 2/30
# 625/625 - 3s - 5ms/step - accuracy: 0.1022 - loss: 3.8843 - val_accuracy: 0.1775 - val_loss: 3.5645
# Epoch 3/30
# 625/625 - 3s - 4ms/step - accuracy: 0.1455 - loss: 3.6428 - val_accuracy: 0.2166 - val_loss: 3.3183
# Epoch 4/30
# 625/625 - 3s - 4ms/step - accuracy: 0.1759 - loss: 3.4766 - val_accuracy: 0.2375 - val_loss: 3.1880
# Epoch 5/30
# 625/625 - 3s - 4ms/step - accuracy: 0.1940 - loss: 3.3593 - val_accuracy: 0.2637 - val_loss: 3.0595
# Epoch 6/30
# 625/625 - 5s - 8ms/step - accuracy: 0.2122 - loss: 3.2717 - val_accuracy: 0.2847 - val_loss: 3.0097
# Epoch 7/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2271 - loss: 3.1858 - val_accuracy: 0.3005 - val_loss: 2.9064
# Epoch 8/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2388 - loss: 3.1295 - val_accuracy: 0.3052 - val_loss: 2.8712
# Epoch 9/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2451 - loss: 3.0817 - val_accuracy: 0.3069 - val_loss: 2.8479
# Epoch 10/30
# 625/625 - 5s - 8ms/step - accuracy: 0.2553 - loss: 3.0326 - val_accuracy: 0.3113 - val_loss: 2.8350
# Epoch 11/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2603 - loss: 3.0041 - val_accuracy: 0.3184 - val_loss: 2.8229
# Epoch 12/30
# 625/625 - 6s - 10ms/step - accuracy: 0.2658 - loss: 2.9659 - val_accuracy: 0.3284 - val_loss: 2.7650
# Epoch 13/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2749 - loss: 2.9271 - val_accuracy: 0.3252 - val_loss: 2.7420
# Epoch 14/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2828 - loss: 2.8949 - val_accuracy: 0.3273 - val_loss: 2.7622
# Epoch 15/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2818 - loss: 2.8775 - val_accuracy: 0.3422 - val_loss: 2.6922
# Epoch 16/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2869 - loss: 2.8497 - val_accuracy: 0.3366 - val_loss: 2.7196
# Epoch 17/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2926 - loss: 2.8241 - val_accuracy: 0.3365 - val_loss: 2.6960
# Epoch 18/30
# 625/625 - 5s - 8ms/step - accuracy: 0.2952 - loss: 2.8035 - val_accuracy: 0.3433 - val_loss: 2.6839
# Epoch 19/30
# 625/625 - 5s - 9ms/step - accuracy: 0.3022 - loss: 2.7757 - val_accuracy: 0.3448 - val_loss: 2.6660
# Epoch 20/30
# 625/625 - 3s - 5ms/step - accuracy: 0.3068 - loss: 2.7626 - val_accuracy: 0.3463 - val_loss: 2.6748
# Epoch 21/30
# 625/625 - 5s - 8ms/step - accuracy: 0.3090 - loss: 2.7438 - val_accuracy: 0.3470 - val_loss: 2.6540
# Epoch 22/30
# 625/625 - 3s - 5ms/step - accuracy: 0.3070 - loss: 2.7323 - val_accuracy: 0.3399 - val_loss: 2.6885
# Epoch 23/30
# 625/625 - 5s - 7ms/step - accuracy: 0.3113 - loss: 2.7065 - val_accuracy: 0.3477 - val_loss: 2.6595
# Epoch 24/30
# 625/625 - 6s - 9ms/step - accuracy: 0.3154 - loss: 2.6975 - val_accuracy: 0.3536 - val_loss: 2.6413
# Epoch 25/30
# 625/625 - 3s - 5ms/step - accuracy: 0.3200 - loss: 2.6781 - val_accuracy: 0.3515 - val_loss: 2.6611
# Epoch 26/30
# 625/625 - 5s - 8ms/step - accuracy: 0.3190 - loss: 2.6667 - val_accuracy: 0.3546 - val_loss: 2.6372
# Epoch 27/30
# 625/625 - 5s - 8ms/step - accuracy: 0.3247 - loss: 2.6461 - val_accuracy: 0.3482 - val_loss: 2.6428
# Epoch 28/30
# 625/625 - 3s - 4ms/step - accuracy: 0.3262 - loss: 2.6394 - val_accuracy: 0.3461 - val_loss: 2.6795
# Epoch 29/30
# 625/625 - 3s - 4ms/step - accuracy: 0.3270 - loss: 2.6246 - val_accuracy: 0.3457 - val_loss: 2.6599
# Epoch 30/30
# 625/625 - 3s - 4ms/step - accuracy: 0.3329 - loss: 2.6076 - val_accuracy: 0.3534 - val_loss: 2.6608
# ✅ Fold 3 Accuracy: 0.3546
#
# 🌟 Fold 4/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 625/625 - 6s - 10ms/step - accuracy: 0.0488 - loss: 4.3294 - val_accuracy: 0.1018 - val_loss: 3.9103
# Epoch 2/30
# 625/625 - 3s - 4ms/step - accuracy: 0.1091 - loss: 3.8657 - val_accuracy: 0.1854 - val_loss: 3.4666
# Epoch 3/30
# 625/625 - 3s - 5ms/step - accuracy: 0.1517 - loss: 3.6038 - val_accuracy: 0.2196 - val_loss: 3.2982
# Epoch 4/30
# 625/625 - 5s - 8ms/step - accuracy: 0.1801 - loss: 3.4520 - val_accuracy: 0.2340 - val_loss: 3.2190
# Epoch 5/30
# 625/625 - 3s - 5ms/step - accuracy: 0.1972 - loss: 3.3396 - val_accuracy: 0.2598 - val_loss: 3.0878
# Epoch 6/30
# 625/625 - 5s - 8ms/step - accuracy: 0.2123 - loss: 3.2590 - val_accuracy: 0.2773 - val_loss: 2.9853
# Epoch 7/30
# 625/625 - 5s - 8ms/step - accuracy: 0.2252 - loss: 3.1866 - val_accuracy: 0.2823 - val_loss: 2.9678
# Epoch 8/30
# 625/625 - 2s - 4ms/step - accuracy: 0.2338 - loss: 3.1341 - val_accuracy: 0.2970 - val_loss: 2.8864
# Epoch 9/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2451 - loss: 3.0811 - val_accuracy: 0.2988 - val_loss: 2.8757
# Epoch 10/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2516 - loss: 3.0378 - val_accuracy: 0.3068 - val_loss: 2.8321
# Epoch 11/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2605 - loss: 3.0006 - val_accuracy: 0.3117 - val_loss: 2.7985
# Epoch 12/30
# 625/625 - 5s - 9ms/step - accuracy: 0.2647 - loss: 2.9608 - val_accuracy: 0.3155 - val_loss: 2.7690
# Epoch 13/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2712 - loss: 2.9299 - val_accuracy: 0.3212 - val_loss: 2.7787
# Epoch 14/30
# 625/625 - 2s - 4ms/step - accuracy: 0.2783 - loss: 2.8935 - val_accuracy: 0.3269 - val_loss: 2.7329
# Epoch 15/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2866 - loss: 2.8656 - val_accuracy: 0.3241 - val_loss: 2.7539
# Epoch 16/30
# 625/625 - 6s - 9ms/step - accuracy: 0.2889 - loss: 2.8443 - val_accuracy: 0.3284 - val_loss: 2.7010
# Epoch 17/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2912 - loss: 2.8210 - val_accuracy: 0.3278 - val_loss: 2.7231
# Epoch 18/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2983 - loss: 2.7990 - val_accuracy: 0.3322 - val_loss: 2.7187
# Epoch 19/30
# 625/625 - 5s - 9ms/step - accuracy: 0.2998 - loss: 2.7826 - val_accuracy: 0.3226 - val_loss: 2.7323
# Epoch 20/30
# 625/625 - 5s - 7ms/step - accuracy: 0.3070 - loss: 2.7613 - val_accuracy: 0.3333 - val_loss: 2.6935
# Epoch 21/30
# 625/625 - 3s - 4ms/step - accuracy: 0.3054 - loss: 2.7389 - val_accuracy: 0.3298 - val_loss: 2.7013
# Epoch 22/30
# 625/625 - 6s - 9ms/step - accuracy: 0.3106 - loss: 2.7246 - val_accuracy: 0.3297 - val_loss: 2.7139
# Epoch 23/30
# 625/625 - 5s - 8ms/step - accuracy: 0.3144 - loss: 2.7097 - val_accuracy: 0.3356 - val_loss: 2.7095
# Epoch 24/30
# 625/625 - 5s - 8ms/step - accuracy: 0.3161 - loss: 2.6891 - val_accuracy: 0.3397 - val_loss: 2.6694
# Epoch 25/30
# 625/625 - 3s - 5ms/step - accuracy: 0.3201 - loss: 2.6764 - val_accuracy: 0.3386 - val_loss: 2.6615
# Epoch 26/30
# 625/625 - 5s - 7ms/step - accuracy: 0.3239 - loss: 2.6633 - val_accuracy: 0.3337 - val_loss: 2.7134
# Epoch 27/30
# 625/625 - 6s - 9ms/step - accuracy: 0.3236 - loss: 2.6495 - val_accuracy: 0.3440 - val_loss: 2.6739
# Epoch 28/30
# 625/625 - 5s - 8ms/step - accuracy: 0.3257 - loss: 2.6332 - val_accuracy: 0.3409 - val_loss: 2.6824
# Epoch 29/30
# 625/625 - 3s - 4ms/step - accuracy: 0.3322 - loss: 2.6124 - val_accuracy: 0.3453 - val_loss: 2.6703
# Epoch 30/30
# 625/625 - 2s - 4ms/step - accuracy: 0.3344 - loss: 2.6018 - val_accuracy: 0.3401 - val_loss: 2.6889
# ✅ Fold 4 Accuracy: 0.3386
#
# 🌟 Fold 5/5
# Epoch 1/30
# 625/625 - 6s - 10ms/step - accuracy: 0.0546 - loss: 4.2978 - val_accuracy: 0.1240 - val_loss: 3.8923
# Epoch 2/30
# 625/625 - 3s - 4ms/step - accuracy: 0.1129 - loss: 3.8536 - val_accuracy: 0.1928 - val_loss: 3.4923
# Epoch 3/30
# 625/625 - 3s - 5ms/step - accuracy: 0.1503 - loss: 3.6210 - val_accuracy: 0.2338 - val_loss: 3.3044
# Epoch 4/30
# 625/625 - 3s - 4ms/step - accuracy: 0.1805 - loss: 3.4583 - val_accuracy: 0.2441 - val_loss: 3.1922
# Epoch 5/30
# 625/625 - 2s - 4ms/step - accuracy: 0.2015 - loss: 3.3344 - val_accuracy: 0.2650 - val_loss: 3.0384
# Epoch 6/30
# 625/625 - 2s - 4ms/step - accuracy: 0.2203 - loss: 3.2441 - val_accuracy: 0.2815 - val_loss: 2.9999
# Epoch 7/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2308 - loss: 3.1673 - val_accuracy: 0.3024 - val_loss: 2.8875
# Epoch 8/30
# 625/625 - 5s - 8ms/step - accuracy: 0.2438 - loss: 3.1018 - val_accuracy: 0.3014 - val_loss: 2.9091
# Epoch 9/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2546 - loss: 3.0392 - val_accuracy: 0.3176 - val_loss: 2.7857
# Epoch 10/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2614 - loss: 2.9920 - val_accuracy: 0.3262 - val_loss: 2.7596
# Epoch 11/30
# 625/625 - 5s - 8ms/step - accuracy: 0.2716 - loss: 2.9626 - val_accuracy: 0.3201 - val_loss: 2.7960
# Epoch 12/30
# 625/625 - 3s - 4ms/step - accuracy: 0.2774 - loss: 2.9200 - val_accuracy: 0.3349 - val_loss: 2.7360
# Epoch 13/30
# 625/625 - 2s - 4ms/step - accuracy: 0.2820 - loss: 2.8863 - val_accuracy: 0.3376 - val_loss: 2.7058
# Epoch 14/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2895 - loss: 2.8525 - val_accuracy: 0.3393 - val_loss: 2.7225
# Epoch 15/30
# 625/625 - 3s - 5ms/step - accuracy: 0.2964 - loss: 2.8262 - val_accuracy: 0.3425 - val_loss: 2.6784
# Epoch 16/30
# 625/625 - 2s - 4ms/step - accuracy: 0.3007 - loss: 2.7901 - val_accuracy: 0.3432 - val_loss: 2.6602
# Epoch 17/30
# 625/625 - 2s - 4ms/step - accuracy: 0.3061 - loss: 2.7640 - val_accuracy: 0.3498 - val_loss: 2.6495
# Epoch 18/30
# 625/625 - 3s - 4ms/step - accuracy: 0.3070 - loss: 2.7558 - val_accuracy: 0.3496 - val_loss: 2.6415
# Epoch 19/30
# 625/625 - 5s - 9ms/step - accuracy: 0.3137 - loss: 2.7218 - val_accuracy: 0.3445 - val_loss: 2.6589
# Epoch 20/30
# 625/625 - 5s - 8ms/step - accuracy: 0.3159 - loss: 2.7008 - val_accuracy: 0.3505 - val_loss: 2.6300
# Epoch 21/30
# 625/625 - 5s - 8ms/step - accuracy: 0.3254 - loss: 2.6778 - val_accuracy: 0.3491 - val_loss: 2.6631
# Epoch 22/30
# 625/625 - 3s - 4ms/step - accuracy: 0.3253 - loss: 2.6497 - val_accuracy: 0.3508 - val_loss: 2.6622
# Epoch 23/30
# 625/625 - 3s - 4ms/step - accuracy: 0.3263 - loss: 2.6473 - val_accuracy: 0.3447 - val_loss: 2.6626
# Epoch 24/30
# 625/625 - 6s - 9ms/step - accuracy: 0.3311 - loss: 2.6273 - val_accuracy: 0.3479 - val_loss: 2.6581
# Epoch 25/30
# 625/625 - 2s - 4ms/step - accuracy: 0.3356 - loss: 2.6088 - val_accuracy: 0.3535 - val_loss: 2.6377
# ✅ Fold 5 Accuracy: 0.3505
#
# 📊 Cross-Validation Results:
# Fold 1 Accuracy: 0.3318
# Fold 2 Accuracy: 0.3495
# Fold 3 Accuracy: 0.3546
# Fold 4 Accuracy: 0.3386
# Fold 5 Accuracy: 0.3505
#
# Average Accuracy: 0.3450
# Standard Deviation: 0.0085
